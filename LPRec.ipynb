# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# %cd "/content/drive/MyDrive/LicensePlateRec"
# Out:
# /content/drive/MyDrive/LicensePlateRec

# %%
# !git clone https://github.com/dbolya/yolact.git
# Out:
# Cloning into 'yolact'...
# remote: Enumerating objects: 2936, done.
# remote: Total 2936 (delta 0), reused 0 (delta 0), pack-reused 2936
# Receiving objects: 100% (2936/2936), 21.21 MiB | 17.47 MiB/s, done.
# Resolving deltas: 100% (1997/1997), done.

# %%
# !unzip data.zip

# %%
# !pip install git+https://github.com/philferriere/cocoapi.git#subdirectory=PythonAPI
# Out:
# ...
#   Cloning https://github.com/philferriere/cocoapi.git to /tmp/pip-req-build-qhspfan4
#   Running command git clone -q https://github.com/philferriere/cocoapi.git /tmp/pip-req-build-qhspfan4
# ...
#   Created wheel for pycocotools: filename=pycocotools-2.0-cp36-cp36m-linux_x86_64.whl size=265514 sha256=0bbfd843977ca49ed2b15ad2d63345b37bf0b9476ec0a6bab8cdb1f8a5b79d57
#   Stored in directory: /tmp/pip-ephem-wheel-cache-u_wv1rpn/wheels/69/2b/12/2fa959e49f73d26cff202c2f4e5079096c9c57c8a8509fd75c
# Successfully built pycocotools
# ...
#   Found existing installation: pycocotools 2.0.2
#     Uninstalling pycocotools-2.0.2:
#       Successfully uninstalled pycocotools-2.0.2
# ...

# %%
# !pip install torchvision

# %%
# !wget https://drive.google.com/file/d/1Jy3yCdbatgXa5YYIdTCRrSV0S9V5g1rn/view
# Out:
# --2021-01-23 03:58:42--  https://drive.google.com/file/d/1Jy3yCdbatgXa5YYIdTCRrSV0S9V5g1rn/view
# Resolving drive.google.com (drive.google.com)... 172.217.9.206, 2607:f8b0:4004:803::200e
# Connecting to drive.google.com (drive.google.com)|172.217.9.206|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘view’
#
# view                    [ <=>                ]  68.00K  --.-KB/s    in 0.01s
#
# 2021-01-23 03:58:43 (6.19 MB/s) - ‘view’ saved [69637]

# %%
# %cd yolact
# Out:
# /content/drive/My Drive/LicensePlateRec/yolact

# %%
# !python train.py --config=yolact_resnet50_lp_config

# %%
# !python eval.py --trained_model=./weights/yolact_resnet50_lp_53_1281_interrupt.pth --config=yolact_resnet50_lp_config --score_threshold=0.3 --image="/content/image269.jpg":output.jpg
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/jit/_recursive.py:182: UserWarning: 'lat_layers' was found in ScriptModule constants,  but it is a non-constant submodule. Consider removing it.
#   " but it is a non-constant {}. Consider removing it.".format(name, hint))
# /usr/local/lib/python3.6/dist-packages/torch/jit/_recursive.py:182: UserWarning: 'pred_layers' was found in ScriptModule constants,  but it is a non-constant submodule. Consider removing it.
#   " but it is a non-constant {}. Consider removing it.".format(name, hint))
# /usr/local/lib/python3.6/dist-packages/torch/jit/_recursive.py:182: UserWarning: 'downsample_layers' was found in ScriptModule constants,  but it is a non-constant submodule. Consider removing it.
#   " but it is a non-constant {}. Consider removing it.".format(name, hint))
# Loading model... Done.
